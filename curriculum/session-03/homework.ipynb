# %% [markdown]
# # Session 3 — Homework
#
# **Time estimate:** 2.5–3 hours
#
# **Due:** before Session 4
#
# **Datasets:** Patient CSV from Session 1, NHANES demographics (DEMO_J.XPT) from Session 2.

# %% [markdown]
# ---
#
# ## Part 1 — if/else classification practice (20 min)
#
# Pick three patients from the CSV (any three). For each one, look up their height and weight, compute their BMI, and classify it using if/elif/else:
#
# | BMI | Category |
# |---|---|
# | Below 18.5 | Underweight |
# | 18.5 to 24.9 | Normal |
# | 25.0 to 29.9 | Overweight |
# | 30.0 and above | Obese |
#
# Print a line for each patient like: `Patient P001: BMI = 25.6 → Overweight`
#
# Reminder: BMI = weight_kg / (height_m ** 2). The CSV has height in cm, so divide by 100 first.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 2 — For loop practice (20 min)
#
# Create a list of 5 systolic BP values from the patient CSV (pick any five). Write a for loop that iterates through the list and classifies each value:
#
# - Below 120: Normal
# - 120 to 129: Elevated
# - 130 and above: High
#
# Print one line per value, like: `119 → Normal`

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 3 — Boolean filtering on the patient CSV (30 min)
#
# Load the patient CSV and answer each question with code.

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

csv_path = "/content/drive/MyDrive/YOUR-FOLDER-HERE/session-01/patient_measurements_small.csv"
df = pd.read_csv(csv_path)
df.head()

# %% [markdown]
# **3a.** How many patients are over 40?

# %%
# Your code here

# %% [markdown]
# **3b.** How many female patients are there? Print the filtered DataFrame.

# %%
# Your code here

# %% [markdown]
# **3c.** What's the mean systolic BP for males? For females?

# %%
# Your code here

# %% [markdown]
# **3d.** How many patients have systolic BP above 130? What's their mean age?

# %%
# Your code here

# %% [markdown]
# **3e.** Filter to females over 50. How many are there? What's their mean weight?

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 4 — Group comparison mini-report (30 min)
#
# This is the main artifact for this homework. Produce a printed summary that compares groups.
#
# **4a.** Mean systolic BP by sex. Print two lines:
# ```
# Males (N=10): mean systolic BP = 127.3 mmHg
# Females (N=10): mean systolic BP = 131.5 mmHg
# ```
# (Your numbers will come from the actual data.)

# %%
# Your code here

# %% [markdown]
# **4b.** Mean weight by age bracket. Split patients into two groups: under 45 and 45+. Print:
# ```
# Under 45 (N=X): mean weight = Y kg
# 45 and over (N=X): mean weight = Y kg
# ```

# %%
# Your code here

# %% [markdown]
# **4c.** In 1–2 sentences, describe what you see in these comparisons. Are the groups different? By how much?

# %% [markdown]
# **Your observation:**

# %% [markdown]
# ---
#
# ## Part 5 — NHANES demographics filtering (30 min)
#
# Load the NHANES demographics file from Session 2.
#
# Reminder: `RIDAGEYR` is age in years, `RIAGENDR` is gender (1 = Male, 2 = Female).

# %%
demo = pd.read_sas("/content/drive/MyDrive/YOUR-FOLDER-HERE/session-02/DEMO_J.XPT")
demo.head()

# %% [markdown]
# **5a.** Filter to adults only (age 18 and over). How many adults are in the survey?

# %%
# Your code here

# %% [markdown]
# **5b.** Among all respondents, how many are male (RIAGENDR == 1)? How many are female (RIAGENDR == 2)?

# %%
# Your code here

# %% [markdown]
# **5c.** What's the mean age of adult males? Adult females? Print both.

# %%
# Your code here

# %% [markdown]
# **5d.** Print a summary sentence:
#
# `The NHANES 2017-2018 survey includes N adults. Mean age: males X years, females Y years.`

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 6 — Reflection (10 min)
#
# 1. In your own words, explain step by step what `df[df['age'] > 50]` does.
# 2. Why is the pandas boolean filtering approach better than a for loop for working with DataFrames?
# 3. What's one thing from today you'd explain to a friend?

# %% [markdown]
# **Your answers:**
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
#
# ## Part 7 — Stretch (optional, 20 min)
#
# Only attempt if Parts 1–6 felt comfortable.
#
# Combine two conditions on the NHANES demographics data:
#
# 1. Filter to adult females (RIDAGEYR >= 18 **and** RIAGENDR == 2). How many?
# 2. Filter to seniors (RIDAGEYR >= 65). What fraction of the total survey are they?
# 3. Filter to male seniors. What's their mean age?
#
# Remember: use `&` (not `and`) and wrap each condition in parentheses.

# %%
# Your code here (stretch)

# %% [markdown]
# ---
#
# ## Part 8 — Journal + reference sheet (10 min)
#
# - **Learning journal:** write your Session 3 entry (what clicked, still fuzzy, one word).
# - **Reference sheet:** add at least two entries. Suggested topics:
#   - How boolean filtering works: `df[df['col'] > value]`
#   - The rule about `&` vs `and` in pandas
#   - Parentheses requirement for combining conditions
#   - "Don't loop through DataFrame rows"
#   - Anything that tripped you up

# %% [markdown]
# ---
#
# ## Stuck on something?
#
# 1. Check the `troubleshooting.md` guide in your Drive folder
# 2. Re-read the Session 3 pre-read (especially the if/else and loop examples)
# 3. Ping the WhatsApp group with a screenshot + what you tried
#
# **Do not stare at an error for more than 15 minutes alone.** That's not the deal.
