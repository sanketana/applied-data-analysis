# %% [markdown]
# # Session 1 — Homework
#
# **Time estimate:** 1–1.5 hours (Session 1's homework is lighter than future sessions will be).
#
# **Due:** before Session 2.
#
# **How to submit:** save this notebook in `/session-01/homework.ipynb` in your Drive folder, completed. That's it — the instructor will see it.

# %% [markdown]
# ---
#
# ## What you'll produce
#
# By the end of this homework you will have:
#
# 1. A completed Colab notebook with variables and calculations (this file)
# 2. Three BMI values computed for patients from the CSV
# 3. The first two entries in your learning journal
# 4. At least one entry in your reference sheet

# %% [markdown]
# ---
#
# ## Part 1 — Variables practice (15 min)
#
# Create variables for yourself:
#
# - `my_name` — your name as a string
# - `my_age` — your age as an integer
# - `my_height_m` — your height in metres as a float
# - `my_weight_kg` — your weight in kg as a float
# - `drinks_coffee` — `True` or `False`
#
# Then print each of them, one per line.
#
# (Not comfortable sharing real height/weight? Use made-up values. The numbers don't matter — the practice does.)

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 2 — Compute your BMI (15 min)
#
# Using the variables above, compute your BMI and print it.
#
# Then print a sentence like: `My BMI is 23.5` — look up how to use an *f-string* in Python (one-line search). Add what you learn to your reference sheet.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 3 — Load the patient CSV and compute three BMIs from it (30 min)
#
# Load `patient_measurements_small.csv` from the `/session-01/` folder.
#
# Pick **three rows** from the CSV (any three you like — you can pick by patient_id, like P001, P005, P012).
#
# For each of those three patients, compute their BMI and print it in the format:
#
# `Patient P001: BMI = 25.6`
#
# You don't need pandas tricks for this yet — just read the values off `df.head(20)` and hand-code the BMIs using variables like you did in Part 1. The point is practice, not efficiency.

# %%
# Load the CSV
import pandas as pd

# Your code here

# %%
# View the data

# %%
# Compute and print three BMIs

# %% [markdown]
# ---
#
# ## Part 4 — Reflection (10 min)
#
# In this cell, answer in your own words (2–4 sentences each):
#
# 1. What is a variable, in your own words?
# 2. Why did we have to type `1.65` for height but `45` for age — why different types?
# 3. What surprised you about the patient CSV when you looked at it?
#
# Write your answers in the markdown cell below. (Double-click to edit a markdown cell.)

# %% [markdown]
# **Your answers:**
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
#
# ## Part 5 — Update your journal and reference sheet (10 min)
#
# Open these two files in your Drive folder and update them:
#
# - **`learning-journal.md`** — add your Session 1 entry (what clicked, still fuzzy, one word for today)
# - **`reference-sheet-starter.md`** — add **at least one** thing you learned today that you want to remember. Could be:
#   - The BMI formula
#   - The syntax for f-strings
#   - How to mount Drive in Colab
#   - What Shift+Enter does
#   - Anything else that tripped you up and you want future-you to find quickly

# %% [markdown]
# ---
#
# ## Stuck on something?
#
# 1. Check the `troubleshooting.md` guide in your Drive folder
# 2. Re-read the before-Session-1 setup doc
# 3. Ping the WhatsApp group with a screenshot + what you tried
#
# **Do not stare at an error for more than 15 minutes alone.** That's not the deal.
